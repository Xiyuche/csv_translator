# %%
import pandas as pd

# 替换为你的 CSV 文件路径
csv_file_path = 'split_file_1.csv'

# 读取 CSV 文件
df = pd.read_csv(csv_file_path)

# 将字符串转换为列表，如果不是字符串则将其转换为空列表
df['contexts'] = df['contexts'].apply(lambda x: [x])


df
# Out:
#                                            question  \
# 0                              二禅的特点是什么，以及它与初禅有何不同？
# 1                                    为什么说涅槃并不是一种境界？
# 2                     "在观察法念处时，如何通过观察受的生起与灭掉来消除贪嗔痴？
# 3                          “在佛教冥想中，修习‘观心无常’的目的是什么？”
# 4                                   "为什么皈依后应该亲近善知识？
# 5                    佛陀时代，化相三宝的僧宝包括哪些成员，他们的修行目的是什么？
# 6                                如何通过六根与六尘的接触减少贪嗔痴？
# 7  在菩萨道修行中，哪些布施与持戒行为能助修行者超越生死轮回，实现解脱，并为何这些行为被称为波罗蜜？
# 8                     在修行过程中，如何通过经行和静坐来达到心念了了分明的状态？
# 9                在佛教修行中，对佛、法、僧以及戒律的绝对信心如何影响一个人证悟初果？
#
#                                             contexts  \
# 0  [[�；在坐禅时，进入初禅的时候，身体会有很舒服的感觉，那就是乐。所以进入初禅也称为‘离生喜...
# 1  [[解所执著的渣滓皆丢光。如果追求解脱者想‘得到’解脱，那就是错了，因为解脱是‘什么都得不到...
# 2  [[�用心观察，慢慢的就能掌握消除五盖的方法，它就会消除掉，那我们就不会再怀疑佛法，对它深信...
# 3  [[�、香、味、触、法六尘，称为十八界。我们个别观察它，里面没有一个我，这十八界合起来的一个...
# 4  [[缘使得我们认识到自心，那是非常可贵的，所以我们看到佛、法、僧，要生起如获至宝之想。\n\...
# 5  [[是和合众的意思。奉行佛陀教法的佛陀出家弟子，这些实践佛法的出家弟子都称为僧，他们是比丘、...
# 6  [[�用心观察，慢慢的就能掌握消除五盖的方法，它就会消除掉，那我们就不会再怀疑佛法，对它深信...
# 7  [[�闻到正法，了解人生是很苦恼的，同时也使他们懂得解脱的道理，能令他们走上解脱之道，这三种...
# 8  [[�先修行者要放下一切事物，住在庙宇中，然后跟随一位有资格的导师学习。每天起来，坐禅与经行...
# 9  [[何人都不可毁坏。假如一个人对佛、法、僧以及戒有绝对的信心，一点儿也不怀疑，那他就是断了疑...
#
#                                               answer  \
# 0  二禅的特点包括四支：**内静**、**喜**、**乐**和**一心**。在二禅中，内心达到平...
# 1  涅槃并不是一种境界的原因在于，涅槃的本质是“无生”，而无生意味着不生不灭，因此涅槃不属于有或...
# 2  在观察法念处时，通过观察受的生起与灭掉，可以帮助我们消除贪、嗔、痴的烦恼。首先，我们需要明白...
# 3  在佛教冥想中，修习“观心无常”的目的在于帮助修行者认识到心念的变化与无常性。通过观察六识心的...
# 4  皈依后应该亲近善知识的原因在于，善知识是修行者在学习和实践佛法过程中不可或缺的指导者。善知识...
# 5  佛陀时代，化相三宝的僧宝包括以下成员：\n\n1. **比丘**：出家修行的男性僧侣，遵循佛...
# 6  通过六根与六尘的接触减少贪嗔痴，可以采取以下步骤：\n\n1. **觉察接触**：在静坐时，...
# 7  在菩萨道修行中，以下布施与持戒行为能助修行者超越生死轮回，实现解脱：\n\n### 布施\n...
# 8  在修行过程中，通过经行和静坐可以达到心念了了分明的状态，具体方法如下：\n\n### 经行\...
# 9  在佛教修行中，对佛、法、僧以及戒律的绝对信心对一个人证悟初果具有重要影响。首先，信心是修行的...
#
#                                         ground_truth evolution_type
# 0  二禅的特点是无觉无观，内心平静清净，没有语言的构思，处在清明的状态，被称为“圣默然定”。二禅...         simple
# 1  涅槃并不是一种境界，因为如果涅槃是一种境界，那么它就会有生灭，必然是无常的。然而，涅槃是对不...         simple
# 2  在观察法念处时，通过观察受的生起与灭掉，可以消除贪嗔痴。具体方法是：当六根与六尘接触时，会产...         simple
# 3  在佛教冥想中，修习“观心无常”的目的是对治众生对“常”的执著，帮助人们认识到心念是生灭迅速、...         simple
# 4  皈依后应该亲近善知识，因为通过亲近善知识，我们可以听闻正法，生起正见，并依教奉行。这有助于我...         simple
# 5  在佛陀时代，化相三宝中的僧宝包括比丘、比丘尼、式叉摩那、沙弥、沙弥尼等出家弟子。这些僧宝的成...      reasoning
# 6  通过六根与六尘的接触减少贪嗔痴的方法是：在六根与六尘接触时，仔细观察“受”的生起和消灭过程，...      reasoning
# 7  在菩萨道修行中，助修行者超越生死轮回、实现解脱的布施和持戒行为包括财施、法施、无畏施，以及律...  multi_context
# 8  在修行过程中，通过经行和静坐可以达到心念了了分明的状态。经行时，修行者保持一心前后走动，注意...         simple
# 9  在佛教修行中，对佛、法、僧以及戒律的绝对信心能够帮助一个人证悟初果。这样的信心意味着完全断除...         simple

# %%
from datasets import Dataset

# 创建字典
data_dict = {
    'question': df['question'].tolist(),
    'contexts': df['contexts'].tolist(),
    'answer': df['answer'].tolist(),
    'ground_truth': df['ground_truth'].tolist()  # 如果有其他列，类似地处理
}

# 使用字典创建数据集
hf_dataset = Dataset.from_dict(data_dict)
hf_dataset
# Out:
# Dataset({
#     features: ['question', 'contexts', 'answer', 'ground_truth'],
#     num_rows: 10
# })

# %%
from ragas.metrics import (
    # answer_relevancy,
    faithfulness,
    context_recall,
    context_precision,
    context_entity_recall,
    answer_correctness,
    answer_similarity,
)

# %%
from langchain_openai import ChatOpenAI, OpenAIEmbeddings

# 为embedding设置独立api
openai_key_embedding = 'sk-S52sOieQg04WZzEtNa4gKt52RcJQ3qh6ac8GZfWQhBqQskUg'
# 为chatbot设置独立api，重定向至deepseek
deepseek_key = 'sk-aff8187171d643828da2280bf1846bc0'

llm = ChatOpenAI(model="deepseek-chat", base_url="https://api.deepseek.com/v1", api_key=deepseek_key)

embeddings = OpenAIEmbeddings(model="text-embedding-3-small", base_url="https://api.openai-proxy.org/v1", api_key=openai_key_embedding)

# %%
from ragas import evaluate
from ragas.run_config import RunConfig

result = evaluate(
    hf_dataset,
    metrics=[
    # answer_relevancy,
    faithfulness,
    context_recall,
    context_precision,
    context_entity_recall,
    answer_correctness,
    answer_similarity,
    ],
    llm=llm,
    embeddings=embeddings,
    run_config=RunConfig(max_workers=64)
)

result
# Out:
# Evaluating:   0%|          | 0/60 [00:00<?, ?it/s]
# {'faithfulness': 0.5964, 'context_recall': 1.0000, 'context_precision': 1.0000, 'context_entity_recall': 0.3563, 'answer_correctness': 0.7148, 'answer_similarity': 0.8791}

# %%
df = result.to_pandas()
df
# Out:
#                                            question  \
# 0                              二禅的特点是什么，以及它与初禅有何不同？
# 1                                    为什么说涅槃并不是一种境界？
# 2                     "在观察法念处时，如何通过观察受的生起与灭掉来消除贪嗔痴？
# 3                          “在佛教冥想中，修习‘观心无常’的目的是什么？”
# 4                                   "为什么皈依后应该亲近善知识？
# 5                    佛陀时代，化相三宝的僧宝包括哪些成员，他们的修行目的是什么？
# 6                                如何通过六根与六尘的接触减少贪嗔痴？
# 7  在菩萨道修行中，哪些布施与持戒行为能助修行者超越生死轮回，实现解脱，并为何这些行为被称为波罗蜜？
# 8                     在修行过程中，如何通过经行和静坐来达到心念了了分明的状态？
# 9                在佛教修行中，对佛、法、僧以及戒律的绝对信心如何影响一个人证悟初果？
#
#                                             contexts  \
# 0  [[�；在坐禅时，进入初禅的时候，身体会有很舒服的感觉，那就是乐。所以进入初禅也称为‘离生喜...
# 1  [[解所执著的渣滓皆丢光。如果追求解脱者想‘得到’解脱，那就是错了，因为解脱是‘什么都得不到...
# 2  [[�用心观察，慢慢的就能掌握消除五盖的方法，它就会消除掉，那我们就不会再怀疑佛法，对它深信...
# 3  [[�、香、味、触、法六尘，称为十八界。我们个别观察它，里面没有一个我，这十八界合起来的一个...
# 4  [[缘使得我们认识到自心，那是非常可贵的，所以我们看到佛、法、僧，要生起如获至宝之想。\n\...
# 5  [[是和合众的意思。奉行佛陀教法的佛陀出家弟子，这些实践佛法的出家弟子都称为僧，他们是比丘、...
# 6  [[�用心观察，慢慢的就能掌握消除五盖的方法，它就会消除掉，那我们就不会再怀疑佛法，对它深信...
# 7  [[�闻到正法，了解人生是很苦恼的，同时也使他们懂得解脱的道理，能令他们走上解脱之道，这三种...
# 8  [[�先修行者要放下一切事物，住在庙宇中，然后跟随一位有资格的导师学习。每天起来，坐禅与经行...
# 9  [[何人都不可毁坏。假如一个人对佛、法、僧以及戒有绝对的信心，一点儿也不怀疑，那他就是断了疑...
#
#                                               answer  \
# 0  二禅的特点包括四支：**内静**、**喜**、**乐**和**一心**。在二禅中，内心达到平...
# 1  涅槃并不是一种境界的原因在于，涅槃的本质是“无生”，而无生意味着不生不灭，因此涅槃不属于有或...
# 2  在观察法念处时，通过观察受的生起与灭掉，可以帮助我们消除贪、嗔、痴的烦恼。首先，我们需要明白...
# 3  在佛教冥想中，修习“观心无常”的目的在于帮助修行者认识到心念的变化与无常性。通过观察六识心的...
# 4  皈依后应该亲近善知识的原因在于，善知识是修行者在学习和实践佛法过程中不可或缺的指导者。善知识...
# 5  佛陀时代，化相三宝的僧宝包括以下成员：\n\n1. **比丘**：出家修行的男性僧侣，遵循佛...
# 6  通过六根与六尘的接触减少贪嗔痴，可以采取以下步骤：\n\n1. **觉察接触**：在静坐时，...
# 7  在菩萨道修行中，以下布施与持戒行为能助修行者超越生死轮回，实现解脱：\n\n### 布施\n...
# 8  在修行过程中，通过经行和静坐可以达到心念了了分明的状态，具体方法如下：\n\n### 经行\...
# 9  在佛教修行中，对佛、法、僧以及戒律的绝对信心对一个人证悟初果具有重要影响。首先，信心是修行的...
#
#                                         ground_truth  faithfulness  \
# 0  二禅的特点是无觉无观，内心平静清净，没有语言的构思，处在清明的状态，被称为“圣默然定”。二禅...      0.800000
# 1  涅槃并不是一种境界，因为如果涅槃是一种境界，那么它就会有生灭，必然是无常的。然而，涅槃是对不...      0.428571
# 2  在观察法念处时，通过观察受的生起与灭掉，可以消除贪嗔痴。具体方法是：当六根与六尘接触时，会产...      0.600000
# 3  在佛教冥想中，修习“观心无常”的目的是对治众生对“常”的执著，帮助人们认识到心念是生灭迅速、...      0.750000
# 4  皈依后应该亲近善知识，因为通过亲近善知识，我们可以听闻正法，生起正见，并依教奉行。这有助于我...      0.600000
# 5  在佛陀时代，化相三宝中的僧宝包括比丘、比丘尼、式叉摩那、沙弥、沙弥尼等出家弟子。这些僧宝的成...      0.000000
# 6  通过六根与六尘的接触减少贪嗔痴的方法是：在六根与六尘接触时，仔细观察“受”的生起和消灭过程，...      1.000000
# 7  在菩萨道修行中，助修行者超越生死轮回、实现解脱的布施和持戒行为包括财施、法施、无畏施，以及律...      0.750000
# 8  在修行过程中，通过经行和静坐可以达到心念了了分明的状态。经行时，修行者保持一心前后走动，注意...      0.750000
# 9  在佛教修行中，对佛、法、僧以及戒律的绝对信心能够帮助一个人证悟初果。这样的信心意味着完全断除...      0.285714
#
#    context_recall  context_precision  context_entity_recall  \
# 0             1.0                1.0               0.000000
# 1             1.0                1.0               0.000000
# 2             1.0                1.0               0.666667
# 3             1.0                1.0               0.000000
# 4             1.0                1.0               0.666667
# 5             1.0                1.0               0.800000
# 6             1.0                1.0               0.500000
# 7             1.0                1.0               0.111111
# 8             1.0                1.0               0.000000
# 9             1.0                1.0               0.818182
#
#    answer_correctness  answer_similarity
# 0            0.978504           0.914016
# 1            0.970888           0.883552
# 2            0.954590           0.818360
# 3            0.227294           0.909177
# 4            0.223378           0.893263
# 5            0.621366           0.885478
# 6            0.815849           0.863456
# 7            0.977740           0.910961
# 8            0.983314           0.933249
# 9            0.394783           0.779132
