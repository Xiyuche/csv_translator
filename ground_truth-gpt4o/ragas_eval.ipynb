# %% [markdown]
# ### 其中的 `answer` 来自于`gpt-4o + question + contexts`
#
# 理论上answer质量更高
# - critic:不总是，需要人工校准，不确定gpt-4o是否总是服从context，及其回答的完备性

# %%
import pandas as pd

# 替换为你的 CSV 文件路径
csv_file_path = 'split_file_1.csv'

# 读取 CSV 文件
df = pd.read_csv(csv_file_path)

# 将字符串转换为列表，如果不是字符串则将其转换为空列表
df['contexts'] = df['contexts'].apply(lambda x: [x])


df
# Out:
#                                            question  \
# 0                              二禅的特点是什么，以及它与初禅有何不同？
# 1                                    为什么说涅槃并不是一种境界？
# 2                     "在观察法念处时，如何通过观察受的生起与灭掉来消除贪嗔痴？
# 3                          “在佛教冥想中，修习‘观心无常’的目的是什么？”
# 4                                   "为什么皈依后应该亲近善知识？
# 5                    佛陀时代，化相三宝的僧宝包括哪些成员，他们的修行目的是什么？
# 6                                如何通过六根与六尘的接触减少贪嗔痴？
# 7  在菩萨道修行中，哪些布施与持戒行为能助修行者超越生死轮回，实现解脱，并为何这些行为被称为波罗蜜？
# 8                     在修行过程中，如何通过经行和静坐来达到心念了了分明的状态？
# 9                在佛教修行中，对佛、法、僧以及戒律的绝对信心如何影响一个人证悟初果？
#
#                                             contexts  \
# 0  [[�；在坐禅时，进入初禅的时候，身体会有很舒服的感觉，那就是乐。所以进入初禅也称为‘离生喜...
# 1  [[解所执著的渣滓皆丢光。如果追求解脱者想‘得到’解脱，那就是错了，因为解脱是‘什么都得不到...
# 2  [[�用心观察，慢慢的就能掌握消除五盖的方法，它就会消除掉，那我们就不会再怀疑佛法，对它深信...
# 3  [[�、香、味、触、法六尘，称为十八界。我们个别观察它，里面没有一个我，这十八界合起来的一个...
# 4  [[缘使得我们认识到自心，那是非常可贵的，所以我们看到佛、法、僧，要生起如获至宝之想。\n\...
# 5  [[是和合众的意思。奉行佛陀教法的佛陀出家弟子，这些实践佛法的出家弟子都称为僧，他们是比丘、...
# 6  [[�用心观察，慢慢的就能掌握消除五盖的方法，它就会消除掉，那我们就不会再怀疑佛法，对它深信...
# 7  [[�闻到正法，了解人生是很苦恼的，同时也使他们懂得解脱的道理，能令他们走上解脱之道，这三种...
# 8  [[�先修行者要放下一切事物，住在庙宇中，然后跟随一位有资格的导师学习。每天起来，坐禅与经行...
# 9  [[何人都不可毁坏。假如一个人对佛、法、僧以及戒有绝对的信心，一点儿也不怀疑，那他就是断了疑...
#
#                                               answer  \
# 0  二禅的特点是无觉无观，内心平静清净，没有语言的构思，处在清明的状态，被称为“圣默然定”。二禅...
# 1  涅槃并不是一种境界，因为如果涅槃是一种境界，那么它就会有生灭，必然是无常的。然而，涅槃是对不...
# 2  在观察法念处时，通过观察受的生起与灭掉，可以消除贪嗔痴。具体方法是：当六根与六尘接触时，会产...
# 3  在佛教冥想中，修习“观心无常”的目的是对治众生对“常”的执著，帮助人们认识到心念是生灭迅速、...
# 4  皈依后应该亲近善知识，因为通过亲近善知识，我们可以听闻正法，生起正见，并依教奉行。这有助于我...
# 5  在佛陀时代，化相三宝中的僧宝包括比丘、比丘尼、式叉摩那、沙弥、沙弥尼等出家弟子。这些僧宝的成...
# 6  通过六根与六尘的接触减少贪嗔痴的方法是：在六根与六尘接触时，仔细观察“受”的生起和消灭过程，...
# 7  在菩萨道修行中，助修行者超越生死轮回、实现解脱的布施和持戒行为包括财施、法施、无畏施，以及律...
# 8  在修行过程中，通过经行和静坐可以达到心念了了分明的状态。经行时，修行者保持一心前后走动，注意...
# 9  在佛教修行中，对佛、法、僧以及戒律的绝对信心能够帮助一个人证悟初果。这样的信心意味着完全断除...
#
#                                         ground_truth evolution_type
# 0  二禅的特点包括无觉无观、内心平静、清净、无眼、耳、身识，唯有意识，以及具有内静、喜、乐、一心...         simple
# 1  涅槃并不是一种境界，因为如果涅槃是一种境界，能进入那种境界，必然能够出，有进、有出，就是有生...         simple
# 2  在观察法念处时，通过观察受的生起与灭掉，可以消除贪嗔痴。一旦你看到受的生起、再灭掉，那么我们...         simple
# 3  佛教冥想中实践“观心无常”的目的在于认识到心念始终处于变化之中，并无恒定不变的状态，从而有助...         simple
# 4  皈依后应该亲近善知识，因为亲近善知识可以帮助我们听闻正法，生起正见，并且依教奉行，以僧为榜样...         simple
# 5  佛陀时代，化相三宝的僧宝包括无数出家的凡圣弟子，他们的修行目的是依据佛法修行，结果解脱证果，...      reasoning
# 6  通过观察六根与六尘的接触，了了分明受的生起和灭掉，可以减少贪嗔痴。例如，当有人骂你时，通过观...      reasoning
# 7  在菩萨道修行中，闻到正法、了解人生苦恼、懂得解脱道理的布施，以及持戒中的律仪戒、摄善法戒、饶...  multi_context
# 8  在修行过程中，通过经行和静坐来达到心念了了分明的状态，主要是通过观察身体的一举一动和呼吸的出...         simple
# 9  在佛教修行中，对佛、法、僧以及戒律的绝对信心可以断除疑结，使一个人证悟到初果。如果学佛者对这...         simple

# %%
from datasets import Dataset

# 创建字典
data_dict = {
    'question': df['question'].tolist(),
    'contexts': df['contexts'].tolist(),
    'answer': df['answer'].tolist(),
    'ground_truth': df['ground_truth'].tolist()  # 如果有其他列，类似地处理
}

# 使用字典创建数据集
hf_dataset = Dataset.from_dict(data_dict)
hf_dataset
# Out:
# Dataset({
#     features: ['question', 'contexts', 'answer', 'ground_truth'],
#     num_rows: 10
# })

# %%
from ragas.metrics import (
    # answer_relevancy,
    faithfulness,
    context_recall,
    context_precision,
    context_entity_recall,
    answer_correctness,
    answer_similarity,
)

# %%
from langchain_openai import ChatOpenAI, OpenAIEmbeddings

# 为embedding设置独立api
openai_key_embedding = 'sk-S52sOieQg04WZzEtNa4gKt52RcJQ3qh6ac8GZfWQhBqQskUg'
# 为chatbot设置独立api，重定向至deepseek
# deepseek_key = 'sk-aff8187171d643828da2280bf1846bc0'

llm = ChatOpenAI(model="gpt-4o-mini", base_url="https://api.openai-proxy.org/v1", api_key=openai_key_embedding)

embeddings = OpenAIEmbeddings(model="text-embedding-3-small", base_url="https://api.openai-proxy.org/v1", api_key=openai_key_embedding)

# %%
from ragas import evaluate
from ragas.run_config import RunConfig

result = evaluate(
    hf_dataset,
    metrics=[
    # answer_relevancy,
    faithfulness,
    context_recall,
    context_precision,
    context_entity_recall,
    answer_correctness,
    answer_similarity,
    ],
    llm=llm,
    embeddings=embeddings,
    run_config=RunConfig(max_workers=64)
)

result
# Out:
# Evaluating:   0%|          | 0/60 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 4
#       1 from ragas import evaluate
#       2 from ragas.run_config import RunConfig
# ----> 4 result = evaluate(
#       5     hf_dataset,
#       6     metrics=[
#       7     # answer_relevancy,
#       8     faithfulness,
#       9     context_recall,
#      10     context_precision,
#      11     context_entity_recall,
#      12     answer_correctness,
#      13     answer_similarity,
#      14     ],
#      15     llm=llm,
#      16     embeddings=embeddings,
#      17     run_config=RunConfig(max_workers=64)
#      18 )
#      20 result
#
# File /opt/anaconda3/envs/moreGraph/lib/python3.11/site-packages/ragas/_analytics.py:129, in track_was_completed.<locals>.wrapper(*args, **kwargs)
#     126 @wraps(func)
#     127 def wrapper(*args: P.args, **kwargs: P.kwargs) -> t.Any:
#     128     track(IsCompleteEvent(event_type=func.__name__, is_completed=False))
# --> 129     result = func(*args, **kwargs)
#     130     track(IsCompleteEvent(event_type=func.__name__, is_completed=True))
#     132     return result
#
# File /opt/anaconda3/envs/moreGraph/lib/python3.11/site-packages/ragas/evaluation.py:260, in evaluate(dataset, metrics, llm, embeddings, callbacks, in_ci, run_config, token_usage_parser, raise_exceptions, column_map)
#     257 scores = []
#     258 try:
#     259     # get the results
# --> 260     results = executor.results()
#     261     if results == []:
#     262         raise ExceptionInRunner()
#
# File /opt/anaconda3/envs/moreGraph/lib/python3.11/site-packages/ragas/executor.py:116, in Executor.results(self)
#     112         results.append(r)
#     114     return results
# --> 116 results = asyncio.run(_aresults())
#     117 sorted_results = sorted(results, key=lambda x: x[0])
#     118 return [r[1] for r in sorted_results]
#
# File /opt/anaconda3/envs/moreGraph/lib/python3.11/site-packages/nest_asyncio.py:30, in _patch_asyncio.<locals>.run(main, debug)
#      28 task = asyncio.ensure_future(main)
#      29 try:
# ---> 30     return loop.run_until_complete(task)
#      31 finally:
#      32     if not task.done():
#
# File /opt/anaconda3/envs/moreGraph/lib/python3.11/site-packages/nest_asyncio.py:92, in _patch_loop.<locals>.run_until_complete(self, future)
#      90     f._log_destroy_pending = False
#      91 while not f.done():
# ---> 92     self._run_once()
#      93     if self._stopping:
#      94         break
#
# File /opt/anaconda3/envs/moreGraph/lib/python3.11/site-packages/nest_asyncio.py:115, in _patch_loop.<locals>._run_once(self)
#     108     heappop(scheduled)
#     110 timeout = (
#     111     0 if ready or self._stopping
#     112     else min(max(
#     113         scheduled[0]._when - self.time(), 0), 86400) if scheduled
#     114     else None)
# --> 115 event_list = self._selector.select(timeout)
#     116 self._process_events(event_list)
#     118 end_time = self.time() + self._clock_resolution
#
# File /opt/anaconda3/envs/moreGraph/lib/python3.11/selectors.py:566, in KqueueSelector.select(self, timeout)
#     564 ready = []
#     565 try:
# --> 566     kev_list = self._selector.control(None, max_ev, timeout)
#     567 except InterruptedError:
#     568     return ready
#
# KeyboardInterrupt:

# %%
df = result.to_pandas()
df
# Out:
#                                            question  \
# 0                              二禅的特点是什么，以及它与初禅有何不同？
# 1                                    为什么说涅槃并不是一种境界？
# 2                     "在观察法念处时，如何通过观察受的生起与灭掉来消除贪嗔痴？
# 3                          “在佛教冥想中，修习‘观心无常’的目的是什么？”
# 4                                   "为什么皈依后应该亲近善知识？
# 5                    佛陀时代，化相三宝的僧宝包括哪些成员，他们的修行目的是什么？
# 6                                如何通过六根与六尘的接触减少贪嗔痴？
# 7  在菩萨道修行中，哪些布施与持戒行为能助修行者超越生死轮回，实现解脱，并为何这些行为被称为波罗蜜？
# 8                     在修行过程中，如何通过经行和静坐来达到心念了了分明的状态？
# 9                在佛教修行中，对佛、法、僧以及戒律的绝对信心如何影响一个人证悟初果？
#
#                                             contexts  \
# 0  [[�；在坐禅时，进入初禅的时候，身体会有很舒服的感觉，那就是乐。所以进入初禅也称为‘离生喜...
# 1  [[解所执著的渣滓皆丢光。如果追求解脱者想‘得到’解脱，那就是错了，因为解脱是‘什么都得不到...
# 2  [[�用心观察，慢慢的就能掌握消除五盖的方法，它就会消除掉，那我们就不会再怀疑佛法，对它深信...
# 3  [[�、香、味、触、法六尘，称为十八界。我们个别观察它，里面没有一个我，这十八界合起来的一个...
# 4  [[缘使得我们认识到自心，那是非常可贵的，所以我们看到佛、法、僧，要生起如获至宝之想。\n\...
# 5  [[是和合众的意思。奉行佛陀教法的佛陀出家弟子，这些实践佛法的出家弟子都称为僧，他们是比丘、...
# 6  [[�用心观察，慢慢的就能掌握消除五盖的方法，它就会消除掉，那我们就不会再怀疑佛法，对它深信...
# 7  [[�闻到正法，了解人生是很苦恼的，同时也使他们懂得解脱的道理，能令他们走上解脱之道，这三种...
# 8  [[�先修行者要放下一切事物，住在庙宇中，然后跟随一位有资格的导师学习。每天起来，坐禅与经行...
# 9  [[何人都不可毁坏。假如一个人对佛、法、僧以及戒有绝对的信心，一点儿也不怀疑，那他就是断了疑...
#
#                                               answer  \
# 0  二禅的特点是无觉无观，内心平静清净，没有语言的构思，处在清明的状态，被称为“圣默然定”。二禅...
# 1  涅槃并不是一种境界，因为如果涅槃是一种境界，那么它就会有生灭，必然是无常的。然而，涅槃是对不...
# 2  在观察法念处时，通过观察受的生起与灭掉，可以消除贪嗔痴。具体方法是：当六根与六尘接触时，会产...
# 3  在佛教冥想中，修习“观心无常”的目的是对治众生对“常”的执著，帮助人们认识到心念是生灭迅速、...
# 4  皈依后应该亲近善知识，因为通过亲近善知识，我们可以听闻正法，生起正见，并依教奉行。这有助于我...
# 5  在佛陀时代，化相三宝中的僧宝包括比丘、比丘尼、式叉摩那、沙弥、沙弥尼等出家弟子。这些僧宝的成...
# 6  通过六根与六尘的接触减少贪嗔痴的方法是：在六根与六尘接触时，仔细观察“受”的生起和消灭过程，...
# 7  在菩萨道修行中，助修行者超越生死轮回、实现解脱的布施和持戒行为包括财施、法施、无畏施，以及律...
# 8  在修行过程中，通过经行和静坐可以达到心念了了分明的状态。经行时，修行者保持一心前后走动，注意...
# 9  在佛教修行中，对佛、法、僧以及戒律的绝对信心能够帮助一个人证悟初果。这样的信心意味着完全断除...
#
#                                         ground_truth  faithfulness  \
# 0  二禅的特点包括无觉无观、内心平静、清净、无眼、耳、身识，唯有意识，以及具有内静、喜、乐、一心...      1.000000
# 1  涅槃并不是一种境界，因为如果涅槃是一种境界，能进入那种境界，必然能够出，有进、有出，就是有生...           NaN
# 2  在观察法念处时，通过观察受的生起与灭掉，可以消除贪嗔痴。一旦你看到受的生起、再灭掉，那么我们...      0.666667
# 3  佛教冥想中实践“观心无常”的目的在于认识到心念始终处于变化之中，并无恒定不变的状态，从而有助...           NaN
# 4  皈依后应该亲近善知识，因为亲近善知识可以帮助我们听闻正法，生起正见，并且依教奉行，以僧为榜样...           NaN
# 5  佛陀时代，化相三宝的僧宝包括无数出家的凡圣弟子，他们的修行目的是依据佛法修行，结果解脱证果，...      1.000000
# 6  通过观察六根与六尘的接触，了了分明受的生起和灭掉，可以减少贪嗔痴。例如，当有人骂你时，通过观...      1.000000
# 7  在菩萨道修行中，闻到正法、了解人生苦恼、懂得解脱道理的布施，以及持戒中的律仪戒、摄善法戒、饶...           NaN
# 8  在修行过程中，通过经行和静坐来达到心念了了分明的状态，主要是通过观察身体的一举一动和呼吸的出...      1.000000
# 9  在佛教修行中，对佛、法、僧以及戒律的绝对信心可以断除疑结，使一个人证悟到初果。如果学佛者对这...      0.666667
#
#    context_recall  context_precision  context_entity_recall  \
# 0        1.000000                1.0               0.000000
# 1        1.000000                1.0               0.000000
# 2        0.666667                1.0               0.000000
# 3        1.000000                1.0               0.000000
# 4        1.000000                1.0                    NaN
# 5        1.000000                1.0               0.428571
# 6        1.000000                1.0               0.285714
# 7        1.000000                1.0               0.333333
# 8        1.000000                1.0               0.285714
# 9        1.000000                1.0               0.833333
#
#    answer_correctness  answer_similarity
# 0            0.229073           0.916293
# 1            0.976428           0.905751
# 2            0.970269           0.881013
# 3            0.959822           0.839290
# 4            0.977669           0.910676
# 5            0.511848           0.847410
# 6            0.969877           0.879511
# 7            0.980047           0.920189
# 8            0.599777           0.899106
# 9            0.207128           0.828513
