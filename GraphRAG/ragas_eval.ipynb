# %%
import pandas as pd

# 替换为你的 CSV 文件路径
csv_file_path = 'split_file_1.csv'

# 读取 CSV 文件
df = pd.read_csv(csv_file_path)

# 将字符串转换为列表，如果不是字符串则将其转换为空列表
df['contexts'] = df['contexts'].apply(lambda x: [x])


df
# Out:
#                                            question  \
# 0                              二禅的特点是什么，以及它与初禅有何不同？
# 1                                    为什么说涅槃并不是一种境界？
# 2                     "在观察法念处时，如何通过观察受的生起与灭掉来消除贪嗔痴？
# 3                          “在佛教冥想中，修习‘观心无常’的目的是什么？”
# 4                                   "为什么皈依后应该亲近善知识？
# 5                    佛陀时代，化相三宝的僧宝包括哪些成员，他们的修行目的是什么？
# 6                                如何通过六根与六尘的接触减少贪嗔痴？
# 7  在菩萨道修行中，哪些布施与持戒行为能助修行者超越生死轮回，实现解脱，并为何这些行为被称为波罗蜜？
# 8                     在修行过程中，如何通过经行和静坐来达到心念了了分明的状态？
# 9                在佛教修行中，对佛、法、僧以及戒律的绝对信心如何影响一个人证悟初果？
#
#                                             contexts  \
# 0  [[�；在坐禅时，进入初禅的时候，身体会有很舒服的感觉，那就是乐。所以进入初禅也称为‘离生喜...
# 1  [[解所执著的渣滓皆丢光。如果追求解脱者想‘得到’解脱，那就是错了，因为解脱是‘什么都得不到...
# 2  [[�用心观察，慢慢的就能掌握消除五盖的方法，它就会消除掉，那我们就不会再怀疑佛法，对它深信...
# 3  [[�、香、味、触、法六尘，称为十八界。我们个别观察它，里面没有一个我，这十八界合起来的一个...
# 4  [[缘使得我们认识到自心，那是非常可贵的，所以我们看到佛、法、僧，要生起如获至宝之想。\n\...
# 5  [[是和合众的意思。奉行佛陀教法的佛陀出家弟子，这些实践佛法的出家弟子都称为僧，他们是比丘、...
# 6  [[�用心观察，慢慢的就能掌握消除五盖的方法，它就会消除掉，那我们就不会再怀疑佛法，对它深信...
# 7  [[�闻到正法，了解人生是很苦恼的，同时也使他们懂得解脱的道理，能令他们走上解脱之道，这三种...
# 8  [[�先修行者要放下一切事物，住在庙宇中，然后跟随一位有资格的导师学习。每天起来，坐禅与经行...
# 9  [[何人都不可毁坏。假如一个人对佛、法、僧以及戒有绝对的信心，一点儿也不怀疑，那他就是断了疑...
#
#                                               answer  \
# 0  二禅是禅定修行的一个高级阶段，与初禅相比，二禅的特点在于无觉无观，内心更加平静，不再进行语言...
# 1  涅槃并非一种境界，因为它超越了语言和概念的描述。涅槃是佛教修行的终极目标，代表着烦恼的消除和...
# 2  在观察法念处时，通过细致地观察六根与六尘接触时产生的感受，了解感受的生起与灭去，可以逐渐认识...
# 3  在佛教冥想中，修习“观心无常”的目的是帮助修行者认识到心念的瞬息万变，从而破除对心念恒常不变...
# 4  皈依后亲近善知识是因为善知识能够指导信徒正确修行佛法，帮助他们理解三宝的真正意义，并在修行过...
# 5  佛陀时代的化相三宝中的僧宝包括跟随佛陀的无数出家凡圣弟子，他们的修行目的是依据佛法修行，结果...
# 6  通过观察六根与六尘的接触，可以减少贪嗔痴。六根（眼、耳、鼻、舌、身、意）与六尘（色、声、香、...
# 7  在菩萨道修行中，布施和持戒是六波罗蜜中的两个重要组成部分，它们能助修行者超越生死轮回，实现解...
# 8  在修行过程中，通过经行和静坐可以达到心念了了分明的状态。经行时，修行者需观察身体的每一个动作...
# 9  在佛教修行中，对佛、法、僧以及戒律的绝对信心是证悟初果的关键条件。初果修行者必须对这些核心要...
#
#                                         ground_truth evolution_type
# 0  二禅的特点是无觉无观，内心平静清净，没有语言的构思，处在清明的状态，被称为“圣默然定”。二禅...         simple
# 1  涅槃并不是一种境界，因为如果涅槃是一种境界，那么它就会有生灭，必然是无常的。然而，涅槃是对不...         simple
# 2  在观察法念处时，通过观察受的生起与灭掉，可以消除贪嗔痴。具体方法是：当六根与六尘接触时，会产...         simple
# 3  在佛教冥想中，修习“观心无常”的目的是对治众生对“常”的执著，帮助人们认识到心念是生灭迅速、...         simple
# 4  皈依后应该亲近善知识，因为通过亲近善知识，我们可以听闻正法，生起正见，并依教奉行。这有助于我...         simple
# 5  在佛陀时代，化相三宝中的僧宝包括比丘、比丘尼、式叉摩那、沙弥、沙弥尼等出家弟子。这些僧宝的成...      reasoning
# 6  通过六根与六尘的接触减少贪嗔痴的方法是：在六根与六尘接触时，仔细观察“受”的生起和消灭过程，...      reasoning
# 7  在菩萨道修行中，助修行者超越生死轮回、实现解脱的布施和持戒行为包括财施、法施、无畏施，以及律...  multi_context
# 8  在修行过程中，通过经行和静坐可以达到心念了了分明的状态。经行时，修行者保持一心前后走动，注意...         simple
# 9  在佛教修行中，对佛、法、僧以及戒律的绝对信心能够帮助一个人证悟初果。这样的信心意味着完全断除...         simple

# %%
from datasets import Dataset

# 创建字典
data_dict = {
    'question': df['question'].tolist(),
    'contexts': df['contexts'].tolist(),
    'answer': df['answer'].tolist(),
    'ground_truth': df['ground_truth'].tolist()  # 如果有其他列，类似地处理
}

# 使用字典创建数据集
hf_dataset = Dataset.from_dict(data_dict)
hf_dataset
# Out:
# Dataset({
#     features: ['question', 'contexts', 'answer', 'ground_truth'],
#     num_rows: 10
# })

# %%
from ragas.metrics import (
    # answer_relevancy,
    faithfulness,
    context_recall,
    context_precision,
    context_entity_recall,
    answer_correctness,
    answer_similarity,
)

# %%
from langchain_openai import ChatOpenAI, OpenAIEmbeddings

# 为embedding设置独立api
openai_key_embedding = 'sk-S52sOieQg04WZzEtNa4gKt52RcJQ3qh6ac8GZfWQhBqQskUg'
# 为chatbot设置独立api，重定向至deepseek
# deepseek_key = 'sk-aff8187171d643828da2280bf1846bc0'

llm = ChatOpenAI(model="gpt-4o-mini", base_url="https://api.openai-proxy.org/v1", api_key=openai_key_embedding)

embeddings = OpenAIEmbeddings(model="text-embedding-3-small", base_url="https://api.openai-proxy.org/v1", api_key=openai_key_embedding)

# %%
from ragas import evaluate
from ragas.run_config import RunConfig

result = evaluate(
    hf_dataset,
    metrics=[
    # answer_relevancy,
    faithfulness,
    context_recall,
    context_precision,
    context_entity_recall,
    answer_correctness,
    answer_similarity,
    ],
    llm=llm,
    embeddings=embeddings,
    run_config=RunConfig(max_workers=64)
)

result
# Out:
# Evaluating:   0%|          | 0/60 [00:00<?, ?it/s]
# No statements were generated from the answer.
# No statements were generated from the answer.
# No statements were generated from the answer.
# No statements were generated from the answer.
# No statements were generated from the answer.
# No statements were generated from the answer.
# No statements were generated from the answer.
# No statements were generated from the answer.
# No statements were generated from the answer.
# Exception raised in Job[45]: TimeoutError()
# {'faithfulness': 0.0000, 'context_recall': 0.7750, 'context_precision': 1.0000, 'context_entity_recall': 0.1963, 'answer_correctness': 0.8878, 'answer_similarity': 0.8512}

# %%
df = result.to_pandas()
df
# Out:
#                                            question  \
# 0                              二禅的特点是什么，以及它与初禅有何不同？
# 1                                    为什么说涅槃并不是一种境界？
# 2                     "在观察法念处时，如何通过观察受的生起与灭掉来消除贪嗔痴？
# 3                          “在佛教冥想中，修习‘观心无常’的目的是什么？”
# 4                                   "为什么皈依后应该亲近善知识？
# 5                    佛陀时代，化相三宝的僧宝包括哪些成员，他们的修行目的是什么？
# 6                                如何通过六根与六尘的接触减少贪嗔痴？
# 7  在菩萨道修行中，哪些布施与持戒行为能助修行者超越生死轮回，实现解脱，并为何这些行为被称为波罗蜜？
# 8                     在修行过程中，如何通过经行和静坐来达到心念了了分明的状态？
# 9                在佛教修行中，对佛、法、僧以及戒律的绝对信心如何影响一个人证悟初果？
#
#                                             contexts  \
# 0  [[�；在坐禅时，进入初禅的时候，身体会有很舒服的感觉，那就是乐。所以进入初禅也称为‘离生喜...
# 1  [[解所执著的渣滓皆丢光。如果追求解脱者想‘得到’解脱，那就是错了，因为解脱是‘什么都得不到...
# 2  [[�用心观察，慢慢的就能掌握消除五盖的方法，它就会消除掉，那我们就不会再怀疑佛法，对它深信...
# 3  [[�、香、味、触、法六尘，称为十八界。我们个别观察它，里面没有一个我，这十八界合起来的一个...
# 4  [[缘使得我们认识到自心，那是非常可贵的，所以我们看到佛、法、僧，要生起如获至宝之想。\n\...
# 5  [[是和合众的意思。奉行佛陀教法的佛陀出家弟子，这些实践佛法的出家弟子都称为僧，他们是比丘、...
# 6  [[�用心观察，慢慢的就能掌握消除五盖的方法，它就会消除掉，那我们就不会再怀疑佛法，对它深信...
# 7  [[�闻到正法，了解人生是很苦恼的，同时也使他们懂得解脱的道理，能令他们走上解脱之道，这三种...
# 8  [[�先修行者要放下一切事物，住在庙宇中，然后跟随一位有资格的导师学习。每天起来，坐禅与经行...
# 9  [[何人都不可毁坏。假如一个人对佛、法、僧以及戒有绝对的信心，一点儿也不怀疑，那他就是断了疑...
#
#                                               answer  \
# 0  二禅是禅定修行的一个高级阶段，与初禅相比，二禅的特点在于无觉无观，内心更加平静，不再进行语言...
# 1  涅槃并非一种境界，因为它超越了语言和概念的描述。涅槃是佛教修行的终极目标，代表着烦恼的消除和...
# 2  在观察法念处时，通过细致地观察六根与六尘接触时产生的感受，了解感受的生起与灭去，可以逐渐认识...
# 3  在佛教冥想中，修习“观心无常”的目的是帮助修行者认识到心念的瞬息万变，从而破除对心念恒常不变...
# 4  皈依后亲近善知识是因为善知识能够指导信徒正确修行佛法，帮助他们理解三宝的真正意义，并在修行过...
# 5  佛陀时代的化相三宝中的僧宝包括跟随佛陀的无数出家凡圣弟子，他们的修行目的是依据佛法修行，结果...
# 6  通过观察六根与六尘的接触，可以减少贪嗔痴。六根（眼、耳、鼻、舌、身、意）与六尘（色、声、香、...
# 7  在菩萨道修行中，布施和持戒是六波罗蜜中的两个重要组成部分，它们能助修行者超越生死轮回，实现解...
# 8  在修行过程中，通过经行和静坐可以达到心念了了分明的状态。经行时，修行者需观察身体的每一个动作...
# 9  在佛教修行中，对佛、法、僧以及戒律的绝对信心是证悟初果的关键条件。初果修行者必须对这些核心要...
#
#                                         ground_truth  faithfulness  \
# 0  二禅的特点是无觉无观，内心平静清净，没有语言的构思，处在清明的状态，被称为“圣默然定”。二禅...           NaN
# 1  涅槃并不是一种境界，因为如果涅槃是一种境界，那么它就会有生灭，必然是无常的。然而，涅槃是对不...           NaN
# 2  在观察法念处时，通过观察受的生起与灭掉，可以消除贪嗔痴。具体方法是：当六根与六尘接触时，会产...           NaN
# 3  在佛教冥想中，修习“观心无常”的目的是对治众生对“常”的执著，帮助人们认识到心念是生灭迅速、...           NaN
# 4  皈依后应该亲近善知识，因为通过亲近善知识，我们可以听闻正法，生起正见，并依教奉行。这有助于我...           NaN
# 5  在佛陀时代，化相三宝中的僧宝包括比丘、比丘尼、式叉摩那、沙弥、沙弥尼等出家弟子。这些僧宝的成...           NaN
# 6  通过六根与六尘的接触减少贪嗔痴的方法是：在六根与六尘接触时，仔细观察“受”的生起和消灭过程，...           NaN
# 7  在菩萨道修行中，助修行者超越生死轮回、实现解脱的布施和持戒行为包括财施、法施、无畏施，以及律...           0.0
# 8  在修行过程中，通过经行和静坐可以达到心念了了分明的状态。经行时，修行者保持一心前后走动，注意...           NaN
# 9  在佛教修行中，对佛、法、僧以及戒律的绝对信心能够帮助一个人证悟初果。这样的信心意味着完全断除...           NaN
#
#    context_recall  context_precision  context_entity_recall  \
# 0            1.00                1.0               0.571429
# 1            1.00                1.0               0.000000
# 2            1.00                1.0               0.000000
# 3            0.00                1.0               0.000000
# 4            1.00                1.0               0.400000
# 5            0.00                1.0               0.461538
# 6            1.00                1.0               0.000000
# 7            1.00                1.0                    NaN
# 8            1.00                1.0               0.000000
# 9            0.75                1.0               0.333333
#
#    answer_correctness  answer_similarity
# 0            0.966759           0.867009
# 1            0.945646           0.782696
# 2            0.938543           0.754181
# 3            0.982095           0.928379
# 4            0.973030           0.892121
# 5            0.964573           0.858300
# 6            0.963484           0.853934
# 7            0.211571           0.844939
# 8            0.988651           0.954176
# 9            0.943967           0.775867
