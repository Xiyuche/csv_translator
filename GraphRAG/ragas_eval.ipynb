# %%
import pandas as pd

# 替换为你的 CSV 文件路径
csv_file_path = 'split_file_1.csv'

# 读取 CSV 文件
df = pd.read_csv(csv_file_path)

# 将字符串转换为列表，如果不是字符串则将其转换为空列表
df['contexts'] = df['contexts'].apply(lambda x: [x])


df
# Out:
#                                            question  \
# 0                              二禅的特点是什么，以及它与初禅有何不同？
# 1                                    为什么说涅槃并不是一种境界？
# 2                     "在观察法念处时，如何通过观察受的生起与灭掉来消除贪嗔痴？
# 3                          “在佛教冥想中，修习‘观心无常’的目的是什么？”
# 4                                   "为什么皈依后应该亲近善知识？
# 5                    佛陀时代，化相三宝的僧宝包括哪些成员，他们的修行目的是什么？
# 6                                如何通过六根与六尘的接触减少贪嗔痴？
# 7  在菩萨道修行中，哪些布施与持戒行为能助修行者超越生死轮回，实现解脱，并为何这些行为被称为波罗蜜？
# 8                     在修行过程中，如何通过经行和静坐来达到心念了了分明的状态？
# 9                在佛教修行中，对佛、法、僧以及戒律的绝对信心如何影响一个人证悟初果？
#
#                                             contexts  \
# 0  [[�；在坐禅时，进入初禅的时候，身体会有很舒服的感觉，那就是乐。所以进入初禅也称为‘离生喜...
# 1  [[解所执著的渣滓皆丢光。如果追求解脱者想‘得到’解脱，那就是错了，因为解脱是‘什么都得不到...
# 2  [[�用心观察，慢慢的就能掌握消除五盖的方法，它就会消除掉，那我们就不会再怀疑佛法，对它深信...
# 3  [[�、香、味、触、法六尘，称为十八界。我们个别观察它，里面没有一个我，这十八界合起来的一个...
# 4  [[缘使得我们认识到自心，那是非常可贵的，所以我们看到佛、法、僧，要生起如获至宝之想。\n\...
# 5  [[是和合众的意思。奉行佛陀教法的佛陀出家弟子，这些实践佛法的出家弟子都称为僧，他们是比丘、...
# 6  [[�用心观察，慢慢的就能掌握消除五盖的方法，它就会消除掉，那我们就不会再怀疑佛法，对它深信...
# 7  [[�闻到正法，了解人生是很苦恼的，同时也使他们懂得解脱的道理，能令他们走上解脱之道，这三种...
# 8  [[�先修行者要放下一切事物，住在庙宇中，然后跟随一位有资格的导师学习。每天起来，坐禅与经行...
# 9  [[何人都不可毁坏。假如一个人对佛、法、僧以及戒有绝对的信心，一点儿也不怀疑，那他就是断了疑...
#
#                                               answer  \
# 0  二禅是禅定修行的一个高级阶段，与初禅相比，二禅的特点在于无觉无观，内心更加平静，不再进行语言...
# 1  涅槃并非一种境界，因为它超越了语言和概念的描述。涅槃是佛教修行的终极目标，代表着烦恼的消除和...
# 2  在观察法念处时，通过细致地观察六根与六尘接触时产生的感受，了解感受的生起与灭去，可以逐渐认识...
# 3  在佛教冥想中，修习“观心无常”的目的是帮助修行者认识到心念的瞬息万变，从而破除对心念恒常不变...
# 4  皈依后亲近善知识是因为善知识能够指导信徒正确修行佛法，帮助他们理解三宝的真正意义，并在修行过...
# 5  佛陀时代的化相三宝中的僧宝包括跟随佛陀的无数出家凡圣弟子，他们的修行目的是依据佛法修行，结果...
# 6  通过观察六根与六尘的接触，可以减少贪嗔痴。六根（眼、耳、鼻、舌、身、意）与六尘（色、声、香、...
# 7  在菩萨道修行中，布施和持戒是六波罗蜜中的两个重要组成部分，它们能助修行者超越生死轮回，实现解...
# 8  在修行过程中，通过经行和静坐可以达到心念了了分明的状态。经行时，修行者需观察身体的每一个动作...
# 9  在佛教修行中，对佛、法、僧以及戒律的绝对信心是证悟初果的关键条件。初果修行者必须对这些核心要...
#
#                                         ground_truth evolution_type
# 0  二禅的特点包括无觉无观、内心平静、清净、无眼、耳、身识，唯有意识，以及具有内静、喜、乐、一心...         simple
# 1  涅槃并不是一种境界，因为如果涅槃是一种境界，能进入那种境界，必然能够出，有进、有出，就是有生...         simple
# 2  在观察法念处时，通过观察受的生起与灭掉，可以消除贪嗔痴。一旦你看到受的生起、再灭掉，那么我们...         simple
# 3  佛教冥想中实践“观心无常”的目的在于认识到心念始终处于变化之中，并无恒定不变的状态，从而有助...         simple
# 4  皈依后应该亲近善知识，因为亲近善知识可以帮助我们听闻正法，生起正见，并且依教奉行，以僧为榜样...         simple
# 5  佛陀时代，化相三宝的僧宝包括无数出家的凡圣弟子，他们的修行目的是依据佛法修行，结果解脱证果，...      reasoning
# 6  通过观察六根与六尘的接触，了了分明受的生起和灭掉，可以减少贪嗔痴。例如，当有人骂你时，通过观...      reasoning
# 7  在菩萨道修行中，闻到正法、了解人生苦恼、懂得解脱道理的布施，以及持戒中的律仪戒、摄善法戒、饶...  multi_context
# 8  在修行过程中，通过经行和静坐来达到心念了了分明的状态，主要是通过观察身体的一举一动和呼吸的出...         simple
# 9  在佛教修行中，对佛、法、僧以及戒律的绝对信心可以断除疑结，使一个人证悟到初果。如果学佛者对这...         simple

# %%
from datasets import Dataset

# 创建字典
data_dict = {
    'question': df['question'].tolist(),
    'contexts': df['contexts'].tolist(),
    'answer': df['answer'].tolist(),
    'ground_truth': df['ground_truth'].tolist()  # 如果有其他列，类似地处理
}

# 使用字典创建数据集
hf_dataset = Dataset.from_dict(data_dict)
hf_dataset
# Out:
# Dataset({
#     features: ['question', 'contexts', 'answer', 'ground_truth'],
#     num_rows: 10
# })

# %%
from ragas.metrics import (
    # answer_relevancy,
    faithfulness,
    context_recall,
    context_precision,
    context_entity_recall,
    answer_correctness,
    answer_similarity,
)

# %%
from langchain_openai import ChatOpenAI, OpenAIEmbeddings

# 为embedding设置独立api
openai_key_embedding = 'sk-S52sOieQg04WZzEtNa4gKt52RcJQ3qh6ac8GZfWQhBqQskUg'
# 为chatbot设置独立api，重定向至deepseek
# deepseek_key = 'sk-aff8187171d643828da2280bf1846bc0'

llm = ChatOpenAI(model="gpt-4o-mini", base_url="https://api.openai-proxy.org/v1", api_key=openai_key_embedding)

embeddings = OpenAIEmbeddings(model="text-embedding-3-small", base_url="https://api.openai-proxy.org/v1", api_key=openai_key_embedding)

# %%
from ragas import evaluate
from ragas.run_config import RunConfig

result = evaluate(
    hf_dataset,
    metrics=[
    # answer_relevancy,
    # faithfulness,
    # context_recall,
    # context_precision,
    # context_entity_recall,
    answer_correctness,
    answer_similarity,
    ],
    llm=llm,
    embeddings=embeddings,
    run_config=RunConfig(max_workers=16, max_retries=3, max_wait=30)
)

result
# Out:
# Evaluating:   0%|          | 0/20 [00:00<?, ?it/s]
# {'answer_correctness': 0.8808, 'answer_similarity': 0.8230}

# %%
df = result.to_pandas()
df
# Out:
#                                            question  \
# 0                              二禅的特点是什么，以及它与初禅有何不同？
# 1                                    为什么说涅槃并不是一种境界？
# 2                     "在观察法念处时，如何通过观察受的生起与灭掉来消除贪嗔痴？
# 3                          “在佛教冥想中，修习‘观心无常’的目的是什么？”
# 4                                   "为什么皈依后应该亲近善知识？
# 5                    佛陀时代，化相三宝的僧宝包括哪些成员，他们的修行目的是什么？
# 6                                如何通过六根与六尘的接触减少贪嗔痴？
# 7  在菩萨道修行中，哪些布施与持戒行为能助修行者超越生死轮回，实现解脱，并为何这些行为被称为波罗蜜？
# 8                     在修行过程中，如何通过经行和静坐来达到心念了了分明的状态？
# 9                在佛教修行中，对佛、法、僧以及戒律的绝对信心如何影响一个人证悟初果？
#
#                                             contexts  \
# 0  [[�；在坐禅时，进入初禅的时候，身体会有很舒服的感觉，那就是乐。所以进入初禅也称为‘离生喜...
# 1  [[解所执著的渣滓皆丢光。如果追求解脱者想‘得到’解脱，那就是错了，因为解脱是‘什么都得不到...
# 2  [[�用心观察，慢慢的就能掌握消除五盖的方法，它就会消除掉，那我们就不会再怀疑佛法，对它深信...
# 3  [[�、香、味、触、法六尘，称为十八界。我们个别观察它，里面没有一个我，这十八界合起来的一个...
# 4  [[缘使得我们认识到自心，那是非常可贵的，所以我们看到佛、法、僧，要生起如获至宝之想。\n\...
# 5  [[是和合众的意思。奉行佛陀教法的佛陀出家弟子，这些实践佛法的出家弟子都称为僧，他们是比丘、...
# 6  [[�用心观察，慢慢的就能掌握消除五盖的方法，它就会消除掉，那我们就不会再怀疑佛法，对它深信...
# 7  [[�闻到正法，了解人生是很苦恼的，同时也使他们懂得解脱的道理，能令他们走上解脱之道，这三种...
# 8  [[�先修行者要放下一切事物，住在庙宇中，然后跟随一位有资格的导师学习。每天起来，坐禅与经行...
# 9  [[何人都不可毁坏。假如一个人对佛、法、僧以及戒有绝对的信心，一点儿也不怀疑，那他就是断了疑...
#
#                                               answer  \
# 0  二禅是禅定修行的一个高级阶段，与初禅相比，二禅的特点在于无觉无观，内心更加平静，不再进行语言...
# 1  涅槃并非一种境界，因为它超越了语言和概念的描述。涅槃是佛教修行的终极目标，代表着烦恼的消除和...
# 2  在观察法念处时，通过细致地观察六根与六尘接触时产生的感受，了解感受的生起与灭去，可以逐渐认识...
# 3  在佛教冥想中，修习“观心无常”的目的是帮助修行者认识到心念的瞬息万变，从而破除对心念恒常不变...
# 4  皈依后亲近善知识是因为善知识能够指导信徒正确修行佛法，帮助他们理解三宝的真正意义，并在修行过...
# 5  佛陀时代的化相三宝中的僧宝包括跟随佛陀的无数出家凡圣弟子，他们的修行目的是依据佛法修行，结果...
# 6  通过观察六根与六尘的接触，可以减少贪嗔痴。六根（眼、耳、鼻、舌、身、意）与六尘（色、声、香、...
# 7  在菩萨道修行中，布施和持戒是六波罗蜜中的两个重要组成部分，它们能助修行者超越生死轮回，实现解...
# 8  在修行过程中，通过经行和静坐可以达到心念了了分明的状态。经行时，修行者需观察身体的每一个动作...
# 9  在佛教修行中，对佛、法、僧以及戒律的绝对信心是证悟初果的关键条件。初果修行者必须对这些核心要...
#
#                                         ground_truth  answer_correctness  \
# 0  二禅的特点包括无觉无观、内心平静、清净、无眼、耳、身识，唯有意识，以及具有内静、喜、乐、一心...            0.956527
# 1  涅槃并不是一种境界，因为如果涅槃是一种境界，能进入那种境界，必然能够出，有进、有出，就是有生...            0.933552
# 2  在观察法念处时，通过观察受的生起与灭掉，可以消除贪嗔痴。一旦你看到受的生起、再灭掉，那么我们...            0.910686
# 3  佛教冥想中实践“观心无常”的目的在于认识到心念始终处于变化之中，并无恒定不变的状态，从而有助...            0.961397
# 4  皈依后应该亲近善知识，因为亲近善知识可以帮助我们听闻正法，生起正见，并且依教奉行，以僧为榜样...            0.960538
# 5  佛陀时代，化相三宝的僧宝包括无数出家的凡圣弟子，他们的修行目的是依据佛法修行，结果解脱证果，...            0.983539
# 6  通过观察六根与六尘的接触，了了分明受的生起和灭掉，可以减少贪嗔痴。例如，当有人骂你时，通过观...            0.955632
# 7  在菩萨道修行中，闻到正法、了解人生苦恼、懂得解脱道理的布施，以及持戒中的律仪戒、摄善法戒、饶...            0.202056
# 8  在修行过程中，通过经行和静坐来达到心念了了分明的状态，主要是通过观察身体的一举一动和呼吸的出...            0.979503
# 9  在佛教修行中，对佛、法、僧以及戒律的绝对信心可以断除疑结，使一个人证悟到初果。如果学佛者对这...            0.964433
#
#    answer_similarity
# 0           0.826108
# 1           0.733253
# 2           0.642797
# 3           0.845587
# 4           0.842152
# 5           0.934154
# 6           0.822526
# 7           0.808077
# 8           0.918013
# 9           0.857731

# %%
df.to_csv("eval_by_4omini.csv", index=False)
